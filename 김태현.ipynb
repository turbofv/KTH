# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('201905_201905_연령별인구현황_월간_TEST.xlsx',encoding='euc-kr',skiprows=0,index_col=0)

# %%
data = df
data
# Out:
#                              총인구수     연령구간인구수       0세       1세       2세  \
# 전국  (0000000000)       51,840,339  51,840,339  305,924  348,004  388,602
# 서울특별시  (1100000000)     9,762,062   9,762,062   52,878   57,978   63,331
# 부산광역시  (2600000000)     3,429,595   3,429,595   17,350   20,511   22,989
# 대구광역시  (2700000000)     2,452,291   2,452,291   13,270   15,569   17,741
# 인천광역시  (2800000000)     2,957,179   2,957,179   18,504   20,098   22,475
# 광주광역시  (2900000000)     1,459,003   1,459,003    8,367   10,023   11,466
# 대전광역시  (3000000000)     1,484,398   1,484,398    8,686   10,187   11,665
# 울산광역시  (3100000000)     1,151,685   1,151,685    7,553    8,725   10,029
# 세종특별자치시  (3600000000)     325,777     325,777    3,732    3,995    4,304
# 경기도  (4100000000)      13,145,482  13,145,482   85,066   97,401  109,863
# 강원도  (4200000000)       1,540,776   1,540,776    8,058    9,057    9,920
# 충청북도  (4300000000)      1,599,854   1,599,854    9,807   11,160   12,094
# ...

# %%
df.head()
삼십세이하인구수 = df.iloc[1:,2:33]
삼십세이하인구수 = 삼십세이하인구수. replace(',','', regex=True)
삼십세이하인구수 = 삼십세이하인구수.astype(np.int)
삼십세이하인구수합 = np.sum(삼십세이하인구수, axis=1)
삼십세이하인구수합
# Out:
# 서울특별시  (1100000000)      3128653
# 부산광역시  (2600000000)      1019347
# 대구광역시  (2700000000)       791787
# 인천광역시  (2800000000)       982719
# 광주광역시  (2900000000)       520705
# 대전광역시  (3000000000)       515382
# 울산광역시  (3100000000)       390438
# 세종특별자치시  (3600000000)     123174
# 경기도  (4100000000)        4495359
# 강원도  (4200000000)         454466
# 충청북도  (4300000000)        507479
# 충청남도  (4400000000)        667652
# 전라북도  (4500000000)        559738
# 전라남도  (4600000000)        541359
# 경상북도  (4700000000)        767048
# 경상남도  (4800000000)       1056500
# 제주특별자치도  (5000000000)     224834
# dtype: int64

# %%
도시별인구 = df.iloc[1:,0]

도시별인구 = 도시별인구. replace(',','', regex=True)
도시별인구 = 도시별인구.astype(np.int)
도시별인구
# Out:
# 서울특별시  (1100000000)       9762062
# 부산광역시  (2600000000)       3429595
# 대구광역시  (2700000000)       2452291
# 인천광역시  (2800000000)       2957179
# 광주광역시  (2900000000)       1459003
# 대전광역시  (3000000000)       1484398
# 울산광역시  (3100000000)       1151685
# 세종특별자치시  (3600000000)      325777
# 경기도  (4100000000)        13145482
# 강원도  (4200000000)         1540776
# 충청북도  (4300000000)        1599854
# 충청남도  (4400000000)        2125732
# 전라북도  (4500000000)        1827871
# 전라남도  (4600000000)        1871718
# 경상북도  (4700000000)        2669731
# 경상남도  (4800000000)        3367857
# 제주특별자치도  (5000000000)      669328
# Name: 총인구수, dtype: int32

# %%
인구비율 = 삼십세이하인구수합/도시별인구
인구비율top5=인구비율.sort_values(ascending=False)[:5]
인구비율top5
# Out:
# 세종특별자치시  (3600000000)    0.378093
# 광주광역시  (2900000000)      0.356891
# 대전광역시  (3000000000)      0.347199
# 경기도  (4100000000)        0.341970
# 울산광역시  (3100000000)      0.339015
# dtype: float64

# %%
plt.rc('font', family='Malgun Gothic')
plt.bar(인구비율top5.index,인구비율top5)
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# 2.

# %%
df = pd.read_excel('2019년 05월  교통카드 통계자료.xls', sheet_name=3,encoding='euc-kr',skiprows=1)
df.shape
df
abc = df.iloc[:,3:-1]
abc.loc['선릉']
abc
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: '선릉'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-336-b9f441323eaf> in <module>
#       3 df
#       4 abc = df.iloc[:,3:-1]
# ----> 5 abc.loc['선릉']
#       6 abc
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
# ...

# %%
type(abc)

# %%
df.columns
하차위치 = 13

df0 = df.replace(',','', regex=True)
arr = np.array(df0)
arr.shape
df
# Out:
#     Unnamed: 0 Unnamed: 1  Unnamed: 2    Unnamed: 3     승차  하차    승차.1  \
# 0      2019-05        1호선         150           서울역  1,148  21  11,958
# 1      2019-05        1호선         151            시청     89   5   2,843
# 2      2019-05        1호선         152            종각    116   3   4,576
# 3      2019-05        1호선         153          종로3가    216  16   5,505
# 4      2019-05        1호선         154          종로5가     51   3   2,245
# 5      2019-05        1호선         155           동대문    776  12  17,333
# 6      2019-05        1호선         156           신설동    315  38  11,021
# 7      2019-05        1호선         157           제기동    360   6   5,600
# 8      2019-05        1호선         158  청량리(서울시립대입구)  1,430   9  13,965
# 9      2019-05        1호선         159           동묘앞    136  11   3,712
# 10     2019-05        2호선         201            시청    109   2   1,455
# 11     2019-05        2호선         202         을지로입구    131   3   3,186
# ...

# %%
역이름 = arr[:,3]

# %%
역별하차인원 = arr[:, 하차위치].astype(np.int)
역별하차인원
# Out:
# array([238583, 207024, 295205,  88664, 132023,  33995,  78975,  50517,
#         47066,  33547, 243691, 353816, 166400,  69905,  74464,  45297,
#         43335,  35044,  78905, 134197, 273702,  81737,  44297,  68325,
#         45842, 219549,  31955,  46330, 372585, 321238, 378987, 371194,
#        174428, 139043,  90047,  89455,  53157,  86798,  31090,  74124,
#         41154, 283080,  71894, 139709, 118864, 129257,  94693, 109632,
#        130256, 109908,  53548,  27196,  73288,   4755,   2237,  15899,
#          6166,  11183,  13313,   6701,   2385,  36117,  43985,  36778,
#         19390,  33503,   6267,  24280, 147304, 125682,  55633,  82617,
#             0,  84119,  39721,   9564,  18576, 165965, 127320,  12114,
#         99214,  57548, 199466, 279056,  75312,  24575,  28809,  11166,
#         26235,  27974,  58178,  35685,  32144,  15926,  16759,  23383,
#         36990,  49903,  33705,  66260,  45004,  39847,  47624,  56984,
# ...

# %%
역별승차인원합 = np.sum(역별승차인원, axis=1)
역별하차인원합 = np.sum(역별하차인원, axis=1)
역별승차인원[0], 역별하차인원[0]
# Out:
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# <ipython-input-285-9d5a1d19527a> in <module>
#       1 역별승차인원합 = np.sum(역별승차인원, axis=1)
# ----> 2 역별하차인원합 = np.sum(역별하차인원, axis=1)
#       3 역별승차인원[0], 역별하차인원[0]
#
# ~\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py in sum(a, axis, dtype, out, keepdims, initial)
#    2074
#    2075     return _wrapreduction(a, np.add, 'sum', axis, dtype, out, keepdims=keepdims,
# -> 2076                           initial=initial)
#    2077
#    2078
#
# ~\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      84                 return reduction(axis=axis, out=out, **passkwargs)
#      85
# ---> 86     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      87
#      88
#
# AxisError: axis 1 is out of bounds for array of dimension 1

# %%
k=10 
threshold = np.sort(역별승차인원합)[-k]
threshold
# Out:
# 382801

# %%
mask = 역별승차인원합 >=threshold
역별하차인원합[mask], 역이름[mask]
# Out:
# (array([374685, 150637, 149879, 397532, 221675,  95938,  65515, 110080,
#          65234,  52712]),
#  array(['잠실(송파구청)', '서울대입구(관악구청)', '신림', '구로디지털단지', '신도림', '연신내', '쌍문',
#         '수유(강북구청)', '화곡', '까치산'], dtype=object))

# %%
df.
# Out:
#     Unnamed: 0 Unnamed: 1  Unnamed: 2    Unnamed: 3     승차  하차    승차.1  \
# 0      2019-05        1호선         150           서울역  1,148  21  11,958
# 1      2019-05        1호선         151            시청     89   5   2,843
# 2      2019-05        1호선         152            종각    116   3   4,576
# 3      2019-05        1호선         153          종로3가    216  16   5,505
# 4      2019-05        1호선         154          종로5가     51   3   2,245
# 5      2019-05        1호선         155           동대문    776  12  17,333
# 6      2019-05        1호선         156           신설동    315  38  11,021
# 7      2019-05        1호선         157           제기동    360   6   5,600
# 8      2019-05        1호선         158  청량리(서울시립대입구)  1,430   9  13,965
# 9      2019-05        1호선         159           동묘앞    136  11   3,712
# 10     2019-05        2호선         201            시청    109   2   1,455
# 11     2019-05        2호선         202         을지로입구    131   3   3,186
# ...

# %% [markdown]
# 3.

# %%
df = pd.read_excel('2019년 05월  교통카드 통계자료.xls', sheet_name=3,encoding='euc-kr',skiprows=1)
df.shape
df
# Out:
#     Unnamed: 0 Unnamed: 1  Unnamed: 2    Unnamed: 3     승차  하차    승차.1  \
# 0      2019-05        1호선         150           서울역  1,148  21  11,958
# 1      2019-05        1호선         151            시청     89   5   2,843
# 2      2019-05        1호선         152            종각    116   3   4,576
# 3      2019-05        1호선         153          종로3가    216  16   5,505
# 4      2019-05        1호선         154          종로5가     51   3   2,245
# 5      2019-05        1호선         155           동대문    776  12  17,333
# 6      2019-05        1호선         156           신설동    315  38  11,021
# 7      2019-05        1호선         157           제기동    360   6   5,600
# 8      2019-05        1호선         158  청량리(서울시립대입구)  1,430   9  13,965
# 9      2019-05        1호선         159           동묘앞    136  11   3,712
# 10     2019-05        2호선         201            시청    109   2   1,455
# 11     2019-05        2호선         202         을지로입구    131   3   3,186
# ...

# %%
# Out:
# False

# %%
# Out:
#        Unnamed: 3     승차  하차    승차.1    하차.1    승차.2    하차.2     승차.3  \
# 0             서울역  1,148  21  11,958  10,579  15,684  61,286   44,585
# 1              시청     89   5   2,843   4,674   4,169  24,963    8,926
# 2              종각    116   3   4,576   5,233   4,780  33,366    7,695
# 3            종로3가    216  16   5,505   3,036   4,790  16,235    7,163
# 4            종로5가     51   3   2,245   4,205   3,415  19,150    6,140
# 5             동대문    776  12  17,333   2,452  12,614   9,043   19,979
# 6             신설동    315  38  11,021   2,103  11,002   9,714   22,990
# 7             제기동    360   6   5,600   2,439  10,512  10,759   26,059
# 8    청량리(서울시립대입구)  1,430   9  13,965   3,611  19,600  13,875   50,958
# 9             동묘앞    136  11   3,712     876   3,992   4,354    7,349
# 10             시청    109   2   1,455   1,763   2,686  18,049    6,298
# 11          을지로입구    131   3   3,186   3,296   4,043  31,290    9,838
# ...

# %% [markdown]
# 4.

# %%
df = pd.read_excel('2019년 05월  교통카드 통계자료.xls', sheet_name=2,encoding='euc-kr',skiprows=0,index_col=3)
df.shape
df

# %%
df.head()
subway = df.iloc[:,3:-1]
subway.head()
# Out:
#            유임승차       유임하차     무임승차     무임하차
# 지하철역
# 서울역   1,568,570  1,489,737  247,801  242,107
# 시청      709,821    727,110  112,279  112,016
# 종각    1,204,910  1,151,371  176,083  164,915
# 종로3가    699,000    647,664  408,682  382,809
# 종로5가    561,662    578,374  307,515  295,535

# %%
subway = subway.replace(',','',regex=True)
subway = subway.astype('int')

# %%
유임승차 = subway['유임승차']
무임승차 = subway['무임승차']
비율 = 무임승차/유임승차
비율
# Out:
# 지하철역
# 서울역             0.157979
# 시청              0.158179
# 종각              0.146138
# 종로3가            0.584667
# 종로5가            0.547509
# 동대문             0.448670
# 신설동             0.340329
# 제기동             1.189410
# 청량리(서울시립대입구)    0.699576
# 동묘앞             0.836922
# 시청              0.087832
# 을지로입구           0.084048
# 을지로3가           0.152041
# 을지로4가           0.336251
# 동대문역사문화공원       0.116917
# 신당              0.296714
# 상왕십리            0.189488
# 왕십리(성동구청)       0.107824
# 한양대             0.043650
# 뚝섬              0.123619
# 성수              0.144105
# 건대입구            0.076206
# 구의(광진구청)        0.176373
# 강변(동서울터미널)      0.122221
# 잠실나루            0.225764
# 잠실(송파구청)        0.091765
# 잠실새내            0.175870
# 종합운동장           0.147752
# 삼성(무역센터)        0.075654
# 선릉              0.160749
#                   ...
# 공항화물청사          0.131521
# 인천공항1터미널        0.096645
# 인천공항2터미널        0.114779
# 영종              0.269047
# 언주              0.113976
# ...

# %%
y = 비율.sort_values(ascending=False)[:5]

# %%
y
# Out:
# 지하철역
# 소요산    1.609434
# 제기동    1.189410
# 용문     1.155710
# 원덕     1.031139
# 굴봉산    0.941235
# dtype: float64

# %%
plt.title('유임 승차에 비해 무임 승차 비율이 가장 높은 역 5개',fontsize=20)

plt.pie(y, labels=y.index,autopct='%d')
# Out:
# ([<matplotlib.patches.Wedge at 0x250ac65a1d0>,
# ...
#  [Text(0.7234267009728297, 0.828645767695442, '소요산'),
#   Text(-0.7624490452845858, 0.7928880459085154, '제기동'),
#   Text(-0.9961271699320433, -0.46661618202027494, '용문'),
#   Text(0.029065796013099183, -1.099615923630667, '원덕'),
#   Text(0.965917724085151, -0.5263106974954644, '굴봉산')],
#  [Text(0.39459638234881617, 0.4519886005611501, '27'),
#   Text(-0.4158812974279558, 0.432484388677372, '20'),
#   Text(-0.5433420926902054, -0.2545179174656045, '19'),
#   Text(0.01585407055259955, -0.5997905037985456, '17'),
#   Text(0.526864213137355, -0.2870785622702533, '15')])

# %% [markdown]
# 5.

# %%
df = pd.read_html('https://finance.naver.com/sise/sise_market_sum.nhn', header=1, index_col=0,encoding='euc-kr')
df
# Out:
# [      매도호가      전일거래량  자산총계(억)    영업이익증가율  ROE(%)
#  시가
#  고가   매수총잔량      외국인비율  부채총계(억)   당기순이익(억)  ROA(%)
#  저가   매도총잔량  상장주식수(천주)   매출액(억)   주당순이익(원)  PBR(배)
#  NaN    NaN        NaN   매출액증가율  보통주배당금(원)  유보율(%),
#       Unnamed: 1  Unnamed: 2  Unnamed: 3 Unnamed: 4  Unnamed: 5  Unnamed: 6  \
#  1.0        삼성전자     45700.0       100.0     +0.22%       100.0   2728191.0
#  2.0      SK하이닉스     68900.0      2200.0     +3.30%      5000.0    501594.0
#  3.0       삼성전자우     37550.0       100.0     +0.27%       100.0    308994.0
#  4.0         현대차    141000.0       500.0     -0.35%      5000.0    301272.0
#  5.0        셀트리온    208000.0         0.0      0.00%      1000.0    266924.0
#  NaN         NaN         NaN         NaN        NaN         NaN         NaN
#  NaN         NaN         NaN         NaN        NaN         NaN         NaN
#  NaN         NaN         NaN         NaN        NaN         NaN         NaN
# ...

# %%
len(df)
# Out:
# 2

# %%
type(df)
# Out:
# list

# %%
wise = df[1]

# %%
wise
# Out:
#      Unnamed: 1  Unnamed: 2  Unnamed: 3 Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 1.0        삼성전자     45700.0       100.0     +0.22%       100.0   2728191.0
# 2.0      SK하이닉스     68900.0      2200.0     +3.30%      5000.0    501594.0
# 3.0       삼성전자우     37550.0       100.0     +0.27%       100.0    308994.0
# 4.0         현대차    141000.0       500.0     -0.35%      5000.0    301272.0
# 5.0        셀트리온    208000.0         0.0      0.00%      1000.0    266924.0
# NaN         NaN         NaN         NaN        NaN         NaN         NaN
# NaN         NaN         NaN         NaN        NaN         NaN         NaN
# NaN         NaN         NaN         NaN        NaN         NaN         NaN
# 6.0        LG화학    348500.0      3500.0     -0.99%      5000.0    246014.0
# 7.0       현대모비스    233000.0      1000.0     +0.43%      5000.0    222065.0
# 8.0       POSCO    242500.0      2500.0     -1.02%      5000.0    211428.0
# ...

# %%
wise_save = wise.iloc[:,0:-1]
wise_save
wise_save = wise_save.replace('%','',regex=True)
wise_save
wise_save.dropna()
# Out:
#      Unnamed: 1  Unnamed: 2  Unnamed: 3 Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 1.0        삼성전자     45700.0       100.0      +0.22       100.0   2728191.0
# 2.0      SK하이닉스     68900.0      2200.0      +3.30      5000.0    501594.0
# 4.0         현대차    141000.0       500.0      -0.35      5000.0    301272.0
# 5.0        셀트리온    208000.0         0.0       0.00      1000.0    266924.0
# 6.0        LG화학    348500.0      3500.0      -0.99      5000.0    246014.0
# 7.0       현대모비스    233000.0      1000.0      +0.43      5000.0    222065.0
# 8.0       POSCO    242500.0      2500.0      -1.02      5000.0    211428.0
# 9.0        신한지주     44400.0       550.0      -1.22      5000.0    210545.0
# 10.0      SK텔레콤    260000.0      1000.0      +0.39       500.0    209939.0
# 11.0   삼성바이오로직스    313000.0         0.0       0.00      2500.0    207096.0
# 12.0     LG생활건강   1303000.0     17000.0      -1.29      5000.0    203505.0
# ...
