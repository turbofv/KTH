# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
url = 'https://finance.naver.com/item/sise_day.nhn?code=147760'

# %%
tables = pd.read_html(url+'&page='+str(1), encoding='euc-kr')
len(tables)
# Out:
# 2

# %%
tables[0]
# Out:
#             날짜      종가     전일비      시가      고가      저가        거래량
# 0          NaN     NaN     NaN     NaN     NaN     NaN        NaN
# 1   2019.07.03  6140.0  1410.0  4840.0  6140.0  4775.0  8484866.0
# 2   2019.07.02  4730.0   260.0  4490.0  4745.0  4470.0    70726.0
# 3   2019.07.01  4470.0    30.0  4500.0  4520.0  4390.0   104616.0
# 4   2019.06.28  4500.0    60.0  4570.0  4620.0  4350.0    44284.0
# 5   2019.06.27  4560.0    95.0  4655.0  4730.0  4500.0    49991.0
# 6          NaN     NaN     NaN     NaN     NaN     NaN        NaN
# 7          NaN     NaN     NaN     NaN     NaN     NaN        NaN
# 8          NaN     NaN     NaN     NaN     NaN     NaN        NaN
# 9   2019.06.26  4655.0    60.0  4760.0  4800.0  4605.0    27724.0
# 10  2019.06.25  4715.0     0.0  4660.0  4715.0  4615.0    49246.0
# 11  2019.06.24  4715.0    40.0  4755.0  4845.0  4645.0    57178.0
# 12  2019.06.21  4755.0    95.0  4865.0  4900.0  4705.0    74549.0
# ...

# %%
micro = tables[0]
micro.shape
micro
# Out:
#             날짜      종가    전일비      시가      고가      저가       거래량
# 0          NaN     NaN    NaN     NaN     NaN     NaN       NaN
# 1   2018.06.11  7400.0   70.0  7540.0  7540.0  7300.0   24202.0
# 2   2018.06.08  7470.0   20.0  7570.0  7570.0  7360.0   37529.0
# 3   2018.06.07  7490.0  150.0  7350.0  7560.0  7260.0   34608.0
# 4   2018.06.05  7340.0  210.0  7130.0  7340.0  7110.0   25145.0
# 5   2018.06.04  7130.0    0.0  7220.0  7310.0  7100.0   29231.0
# 6          NaN     NaN    NaN     NaN     NaN     NaN       NaN
# 7          NaN     NaN    NaN     NaN     NaN     NaN       NaN
# 8          NaN     NaN    NaN     NaN     NaN     NaN       NaN
# 9   2018.06.01  7130.0   20.0  7060.0  7230.0  6980.0   54650.0
# 10  2018.05.31  7110.0   80.0  7190.0  7260.0  6990.0   40944.0
# 11  2018.05.30  7190.0  170.0  7360.0  7430.0  7140.0   40909.0
# 12  2018.05.29  7360.0   10.0  7260.0  7390.0  7130.0   31277.0
# 13  2018.05.28  7350.0  150.0  7340.0  7470.0  7030.0  135563.0
# ...

# %%
micros = []
for i in range(1,28):
    tables = pd.read_html(url+'&page='+str(i))
    micro = tables[0]
    micros.append(micro)
len(micros)
# Out:
# 27

# %%
micros
# Out:
# [            날짜      종가     전일비      시가      고가      저가        거래량
#  0          NaN     NaN     NaN     NaN     NaN     NaN        NaN
#  1   2019.07.03  6140.0  1410.0  4840.0  6140.0  4775.0  8484866.0
#  2   2019.07.02  4730.0   260.0  4490.0  4745.0  4470.0    70726.0
#  3   2019.07.01  4470.0    30.0  4500.0  4520.0  4390.0   104616.0
#  4   2019.06.28  4500.0    60.0  4570.0  4620.0  4350.0    44284.0
#  5   2019.06.27  4560.0    95.0  4655.0  4730.0  4500.0    49991.0
#  6          NaN     NaN     NaN     NaN     NaN     NaN        NaN
#  7          NaN     NaN     NaN     NaN     NaN     NaN        NaN
#  8          NaN     NaN     NaN     NaN     NaN     NaN        NaN
#  9   2019.06.26  4655.0    60.0  4760.0  4800.0  4605.0    27724.0
#  10  2019.06.25  4715.0     0.0  4660.0  4715.0  4615.0    49246.0
#  11  2019.06.24  4715.0    40.0  4755.0  4845.0  4645.0    57178.0
#  12  2019.06.21  4755.0    95.0  4865.0  4900.0  4705.0    74549.0
# ...

# %%
micro = pd.concat(micros)
micro.shape
# Out:
# (405, 7)

# %%
micro
# Out:
#             날짜      종가     전일비      시가      고가      저가        거래량
# 0          NaN     NaN     NaN     NaN     NaN     NaN        NaN
# 1   2019.07.03  6140.0  1410.0  4840.0  6140.0  4775.0  8484866.0
# 2   2019.07.02  4730.0   260.0  4490.0  4745.0  4470.0    70726.0
# 3   2019.07.01  4470.0    30.0  4500.0  4520.0  4390.0   104616.0
# 4   2019.06.28  4500.0    60.0  4570.0  4620.0  4350.0    44284.0
# 5   2019.06.27  4560.0    95.0  4655.0  4730.0  4500.0    49991.0
# 6          NaN     NaN     NaN     NaN     NaN     NaN        NaN
# 7          NaN     NaN     NaN     NaN     NaN     NaN        NaN
# 8          NaN     NaN     NaN     NaN     NaN     NaN        NaN
# 9   2019.06.26  4655.0    60.0  4760.0  4800.0  4605.0    27724.0
# 10  2019.06.25  4715.0     0.0  4660.0  4715.0  4615.0    49246.0
# 11  2019.06.24  4715.0    40.0  4755.0  4845.0  4645.0    57178.0
# 12  2019.06.21  4755.0    95.0  4865.0  4900.0  4705.0    74549.0
# ...

# %%
micro.tail()
# Out:
#             날짜      종가    전일비      시가      고가      저가       거래량
# 10  2018.05.31  7110.0   80.0  7190.0  7260.0  6990.0   40944.0
# 11  2018.05.30  7190.0  170.0  7360.0  7430.0  7140.0   40909.0
# 12  2018.05.29  7360.0   10.0  7260.0  7390.0  7130.0   31277.0
# 13  2018.05.28  7350.0  150.0  7340.0  7470.0  7030.0  135563.0
# 14         NaN     NaN    NaN     NaN     NaN     NaN       NaN

# %%
for t in tables:
    print(t.shape)
# Out:
# (366, 7)
# (19, 2)

# %%
micro = micro.set_index('날짜')

# %%
micro
# Out:
#                 종가     전일비      시가      고가      저가        거래량
# 날짜
# NaN            NaN     NaN     NaN     NaN     NaN        NaN
# 2019.07.03  6140.0  1410.0  4840.0  6140.0  4775.0  8484866.0
# 2019.07.02  4730.0   260.0  4490.0  4745.0  4470.0    70726.0
# 2019.07.01  4470.0    30.0  4500.0  4520.0  4390.0   104616.0
# 2019.06.28  4500.0    60.0  4570.0  4620.0  4350.0    44284.0
# 2019.06.27  4560.0    95.0  4655.0  4730.0  4500.0    49991.0
# NaN            NaN     NaN     NaN     NaN     NaN        NaN
# NaN            NaN     NaN     NaN     NaN     NaN        NaN
# NaN            NaN     NaN     NaN     NaN     NaN        NaN
# 2019.06.26  4655.0    60.0  4760.0  4800.0  4605.0    27724.0
# 2019.06.25  4715.0     0.0  4660.0  4715.0  4615.0    49246.0
# 2019.06.24  4715.0    40.0  4755.0  4845.0  4645.0    57178.0
# 2019.06.21  4755.0    95.0  4865.0  4900.0  4705.0    74549.0
# 2019.06.20  4850.0   130.0  4720.0  4930.0  4720.0   230930.0
# ...

# %%
url = 'https://coinmarketcap.com/currencies/bitcoin/historical-data/?start=20180601&end=20190601'

tables = pd.read_html(url)
bitcoin =tables[0]
bitcoin
# Out:
#              Date    Open*     High      Low  Close**       Volume  \
# 0    Jun 01, 2019  8573.84  8625.60  8481.58  8564.02  22488303544
# 1    May 31, 2019  8320.29  8586.66  8172.55  8574.50  25365190957
# 2    May 30, 2019  8661.76  9008.31  8221.27  8319.47  29246528551
# 3    May 29, 2019  8718.59  8755.85  8482.73  8659.49  23473479966
# 4    May 28, 2019  8802.76  8807.02  8634.72  8719.96  24226919267
# 5    May 27, 2019  8674.07  8907.17  8668.70  8805.78  27949839564
# 6    May 26, 2019  8055.21  8687.52  7924.67  8673.22  26677970091
# 7    May 25, 2019  7991.89  8117.93  7965.98  8052.54  22256813107
# 8    May 24, 2019  7881.70  8140.72  7824.45  7987.37  25919126991
# 9    May 23, 2019  7677.27  7943.79  7533.20  7881.85  24457107820
# 10   May 22, 2019  7956.29  7997.61  7615.99  7680.07  24719473175
# 11   May 21, 2019  7977.97  8062.17  7843.34  7963.33  25127245056
# 12   May 20, 2019  8196.92  8200.97  7678.78  7978.31  23843404340
# ...

# %%
micro.shape, bitcoin.shape
# Out:
# ((405, 6), (366, 7))

# %%
#micro = micro.set_index('날짜')
bitcoin = bitcoin.set_index('Date')

# %%
bitcoin
# Out:
#                 Open*     High      Low  Close**       Volume    Market Cap
# Date
# Jun 01, 2019  8573.84  8625.60  8481.58  8564.02  22488303544  151890214310
# May 31, 2019  8320.29  8586.66  8172.55  8574.50  25365190957  152059886414
# May 30, 2019  8661.76  9008.31  8221.27  8319.47  29246528551  147525141134
# May 29, 2019  8718.59  8755.85  8482.73  8659.49  23473479966  153537047655
# May 28, 2019  8802.76  8807.02  8634.72  8719.96  24226919267  154590202287
# May 27, 2019  8674.07  8907.17  8668.70  8805.78  27949839564  156093754762
# May 26, 2019  8055.21  8687.52  7924.67  8673.22  26677970091  153725486067
# May 25, 2019  7991.89  8117.93  7965.98  8052.54  22256813107  142708188838
# May 24, 2019  7881.70  8140.72  7824.45  7987.37  25919126991  141539115575
# May 23, 2019  7677.27  7943.79  7533.20  7881.85  24457107820  139654107035
# May 22, 2019  7956.29  7997.61  7615.99  7680.07  24719473175  136063898960
# ...

# %%
pd.to_datetime(bitcoin.index)
# Out:
# DatetimeIndex(['2019-06-01', '2019-05-31', '2019-05-30', '2019-05-29',
#                '2019-05-28', '2019-05-27', '2019-05-26', '2019-05-25',
#                '2019-05-24', '2019-05-23',
#                ...
#                '2018-06-10', '2018-06-09', '2018-06-08', '2018-06-07',
#                '2018-06-06', '2018-06-05', '2018-06-04', '2018-06-03',
#                '2018-06-02', '2018-06-01'],
#               dtype='datetime64[ns]', name='Date', length=366, freq=None)

# %%
pd.to_datetime(micro.index)
# Out:
# DatetimeIndex([       'NaT', '2019-07-03', '2019-07-02', '2019-07-01',
#                '2019-06-28', '2019-06-27',        'NaT',        'NaT',
#                       'NaT', '2019-06-26',
#                ...
#                '2018-06-04',        'NaT',        'NaT',        'NaT',
#                '2018-06-01', '2018-05-31', '2018-05-30', '2018-05-29',
#                '2018-05-28',        'NaT'],
#               dtype='datetime64[ns]', name='날짜', length=405, freq=None)

# %%
# 인덱스 타입을 날짜 타입으로 변환
bitcoin.index = pd.to_datetime(bitcoin.index)
micro.index = pd.to_datetime(micro.index)

# %%
df = pd.concat((micro,bitcoin), axis=1).dropna()
df.shape
# Out:
# (244, 12)

# %%
df
# Out:
#                 종가    전일비      시가      고가      저가        거래량    Open*  \
# 2018-06-01  7130.0   20.0  7060.0  7230.0  6980.0    54650.0  7500.70
# 2018-06-04  7130.0    0.0  7220.0  7310.0  7100.0    29231.0  7722.53
# 2018-06-05  7340.0  210.0  7130.0  7340.0  7110.0    25145.0  7500.90
# 2018-06-07  7490.0  150.0  7350.0  7560.0  7260.0    34608.0  7650.82
# 2018-06-08  7470.0   20.0  7570.0  7570.0  7360.0    37529.0  7685.14
# 2018-06-11  7400.0   70.0  7540.0  7540.0  7300.0    24202.0  6799.29
# 2018-06-12  7360.0   40.0  7310.0  7450.0  7150.0    23585.0  6905.82
# 2018-06-14  7220.0  140.0  7360.0  7390.0  7150.0    10703.0  6342.75
# 2018-06-15  7170.0   50.0  7220.0  7220.0  7060.0    29152.0  6674.08
# 2018-06-18  7010.0  160.0  7170.0  7170.0  6950.0    28827.0  6510.07
# 2018-06-19  6840.0  170.0  7010.0  7090.0  6500.0    51353.0  6742.39
# 2018-06-20  6680.0  160.0  6840.0  6850.0  6600.0    28278.0  6770.76
# ...

# %%
df.dtypes
# Out:
# 종가            float64
# 전일비           float64
# 시가            float64
# 고가            float64
# 저가            float64
# 거래량           float64
# Open*         float64
# High          float64
# Low           float64
# Close**       float64
# Volume        float64
# Market Cap    float64
# dtype: object

# %%
df.describe()
# Out:
#                 종가         전일비           시가           고가           저가  \
# count   244.000000  244.000000   244.000000   244.000000   244.000000
# mean   4742.991803  114.139344  4750.881148  4890.348361  4630.061475
# std     942.010952  123.071448   958.362556   958.555144   926.589112
# min    2900.000000    0.000000  2895.000000  3060.000000  2700.000000
# 25%    4190.000000   35.000000  4190.000000  4280.000000  4085.000000
# 50%    4492.500000   80.000000  4522.500000  4652.500000  4375.000000
# 75%    5020.000000  150.000000  5040.000000  5212.500000  4883.750000
# max    7490.000000  910.000000  7570.000000  7600.000000  7360.000000
#
#                 거래량        Open*         High          Low      Close**  \
# count  2.440000e+02   244.000000   244.000000   244.000000   244.000000
# mean   2.950110e+05  5598.614672  5708.022869  5487.953197  5597.538361
# std    8.949810e+05  1514.608753  1542.730010  1476.931675  1512.541132
# ...

# %%
df.isna().sum().sum() #누락값 없다
# Out:
# 0

# %%
df.cov() # 상관관계
# Out:
#                       종가           전일비            시가            고가  \
# 종가          8.873846e+05  8.091886e+03  8.887295e+05  8.938154e+05
# 전일비         8.091886e+03  1.514658e+04  2.715988e+03  1.676141e+04
# 시가          8.887295e+05  2.715988e+03  9.184588e+05  8.987523e+05
# 고가          8.938154e+05  1.676141e+04  8.987523e+05  9.188280e+05
# 저가          8.661778e+05 -2.866753e+02  8.831070e+05  8.708804e+05
# 거래량        -1.705166e+07  6.059724e+07 -8.965991e+07  3.254196e+07
# Open*       4.085244e+05 -9.725404e+03  4.158669e+05  4.091798e+05
# High        4.180695e+05 -7.719720e+03  4.281608e+05  4.195374e+05
# Low         3.857118e+05 -8.145362e+03  3.944251e+05  3.861558e+05
# Close**     4.010187e+05 -7.084942e+03  4.122927e+05  4.019115e+05
# Volume     -1.272407e+12 -3.425844e+10 -1.326975e+12 -1.350043e+12
# Market Cap  6.276277e+12 -1.283399e+11  6.455264e+12  6.275613e+12
#
#                       저가           거래량         Open*          High  \
# ...

# %%
비트코인변화 = df['Open*'] - df['Close**']
주가변화 = df['시가'] - df['종가']
과거비트코인변화 = 비트코인변화.iloc[:-1]
다음날주가변화 = 주가변화.iloc[1:]

# %%
plt.scatter(과거비트코인변화, 다음날주가변화)

# %%
np.corrcoef(과거비트코인변화,다음날주가변화)
# Out:
# array([[ 1.        , -0.05896657],
#        [-0.05896657,  1.        ]])
